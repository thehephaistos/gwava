# %%
print('hello from group 19!!')
# Out:
# hello from group 19!!

# %%
print("This is a test push - Jayanth")

# %%
import os
import yaml
from pathlib import Path

SCRIPT_DIR = Path.cwd()

yaml_path = SCRIPT_DIR / "GWOSC API.yaml"

with open(yaml_path, "r", encoding="utf-8") as file:
    config = yaml.safe_load(file)

print(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import os
#       2 import yaml
# ----> 4 SCRIPT_DIR = os.path.dirname(os.path.abspath(__file__))
#       6 yaml_path = os.path.join(SCRIPT_DIR, "GWOSC API.yaml")
#       8 with open(yaml_path, "r", encoding="utf-8") as file:
#
# NameError: name '__file__' is not defined
